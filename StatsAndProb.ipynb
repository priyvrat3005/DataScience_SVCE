# %% [markdown]
# ## Todays Topic
#
# #### Why you should learn Stats?
# ##### Lets suppose you want to create a machine learning model to predict the temperature or whether a mil is spa or not or the price of a house will increase or decrease in a particular area
#
# so baically you are doing two things !!!
# 1- We are Quantifying our uncertainty (how sure we are about our prediction )
# 2- we are generalising from a small set of data (Training set ) to predict the future outcomes
#
# we can say that Statistics is mathematical framework that makes these two things possible

# %% [markdown]
# #### Probability is the Grammar of Uncertainty
# ### Probability - Probability is a measure how likely an event is to occur
# lets someone is asking that there are 30% percent of chances it will rain today
#
# P(A)=0  - Event A is immposible
# P(A)=1  - Event is certain
# P(A)=0.5 - it is equaly like to happen or not happen
#
# ### The Components of Prob
#  #### Experiment - Any process that produces an outcome
#  #### Sample Space - Set of all possible outcomes of that experiment
#  #### Event - any subset of the sample space that we care about
#
#     P(A)=Numberof Outcomes in Even A/ Total number of outcomes in Sample space

# %% [markdown]
# ## Suppose we are having a company  and in that company we have total 5000 customer out of them 250 customes churned
# #### What is the probability of randomaly selecting a customer and it is churned ?
#
# ### Experiment - Randomly selecting a customer
# ### Sample Space - All 5000 customers
# ### Event A - The customer churned so there are total 250 customers churned
#
#     P(Churn)= 250/5000=0.05 -> 5%
#
#     that means if we select a random customer there are 5% chances that the customer is churned

# %% [markdown]
# ### Conditional Probability
# Lets suppose we are having total 5000 customers and out of 5000  1000 are on premium plans
# and out of those premium plan customes the churn data was 150
#
# 100 customers are from non premium plans
#
# what is the probabiity that is we'll pick a customer and if its from premium plan what is the churn prob for this
#
# P(A|B)= 150/1000 = 0.15 -> 15%

# %% [markdown]
# if we take 150 customers - These customers are both churners and Premium users both
#
# A^B- a intersection B
#
# A^B and 1000 is the Sample space for Event B
#
# P(A)- 5000
# P(B)- 1000
#  P(A|B)=

# %% [markdown]
# #### Lets Take an example
# you are Data Scientist in an e commerce company so you have to send a promotional email
# to ranom 10,000  customers.
# Now you have to analyse the result
#
# ### Total Recipients - 10,000
# ### Customers who made the purchase (Event A) 300  - P(A) = 3%
# ### Customers who opened the mail  (Event B ) 2000 - P(B) = 20%
# ### Custmers who both opened the mail and made a purchase  (A^B): 240
#
# #### You need to find whats the prob of purchase for someone who opened the mail
# #### Randomly selecting a customer what is the prob he hasnt opend the mail and made the purchase
#
# P(Purchase|Opened) = P(Purchase ^ Opened )/ P(Opened)
#
# p(Purchase|Opened) = 240/2000 - > 0.12 -> 12%
#
# ### CUstomers who hansnt opened the mail but still did the purchase ""?
#
# sample space is  8000
#   E - => 300 - 240= 60
#
#    P(purchase| Didnt opend mail) = 60 /8000  -0.75%
